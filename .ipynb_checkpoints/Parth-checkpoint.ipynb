# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data/merged_df.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0 Animal ID Name_intakes      DateTime_intake MonthYear_intake  \
# 0           0   A786884      A786884  2019-01-03 16:19:00     January 2019
# 1           1   A706918      A706918  2015-07-05 12:59:00        July 2015
# 2           2   A724273      A724273  2016-04-14 18:43:00       April 2016
# 3           3   A665644      A665644  2013-10-21 07:59:00     October 2013
# 4           4   A682524      A682524  2014-06-29 10:38:00        June 2014
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type_intake Sex upon Intake  ...        Date of Birth  \
# 0                Dog   Neutered Male  ...  2017-01-03 00:00:00
# 1                Dog   Spayed Female  ...  2007-07-05 00:00:00
# 2                Dog     Intact Male  ...  2015-04-17 00:00:00
# 3                Cat   Intact Female  ...  2013-09-21 00:00:00
# 4                Dog   Neutered Male  ...  2010-06-29 00:00:00
#
#       Outcome Type Outcome Subtype Animal Type_outcomes Sex upon Outcome  \
# 0         Transfer         Partner                  Dog    Neutered Male
# 1  Return to Owner         Unknown                  Dog    Spayed Female
# 2  Return to Owner         Unknown                  Dog    Neutered Male
# 3         Transfer         Partner                  Cat    Intact Female
# 4  Return to Owner         Unknown                  Dog    Neutered Male
#
#   Age upon Outcome                         Breed_outcomes Color_outcomes  \
# 0          2 years                             Beagle Mix       Tricolor
# 1          8 years               English Springer Spaniel    White/Liver
# 2           1 year                            Basenji Mix    Sable/White
# 3          4 weeks                 Domestic Shorthair Mix         Calico
# 4          4 years  Doberman Pinsch/Australian Cattle Dog       Tan/Gray
#
#       age indicator_col
# 0   735.0          both
# 1  2922.0          both
# 2   370.0          both
# 3    30.0          both
# 4  1464.0          both
#
# [5 rows x 26 columns]

# %% [markdown]
# Analytic 1 - Most common breeds to enter the shelter for Cats and Dogs

# %%
cd=df[(df["Animal Type_outcomes"]=='Dog') | (df['Animal Type_outcomes']=="Cat")]

# %%
temp=cd.groupby(['Animal Type_outcomes','Breed_outcomes'])[['Animal ID']].count().reset_index()
temp.rename(columns={'Animal ID':'Count'},inplace=True)

# %%
temp
# Out:
#      Animal Type_outcomes                                 Breed_outcomes  \
# 0                     Cat                                     Abyssinian
# 1                     Cat                                 Abyssinian Mix
# 2                     Cat                        American Curl Shorthair
# 3                     Cat                    American Curl Shorthair Mix
# 4                     Cat                American Curl Shorthair/Siamese
# ...                   ...                                            ...
# 2525                  Dog  Yorkshire Terrier/Soft Coated Wheaten Terrier
# 2526                  Dog              Yorkshire Terrier/Standard Poodle
# 2527                  Dog           Yorkshire Terrier/Standard Schnauzer
# 2528                  Dog                   Yorkshire Terrier/Toy Poodle
# 2529                  Dog            Yorkshire Terrier/Yorkshire Terrier
#
#       Count
# 0         8
# 1        13
# 2         4
# 3        18
# 4         1
# ...     ...
# 2525      1
# 2526      5
# 2527      4
# 2528     11
# 2529      1
#
# [2530 rows x 3 columns]

# %%
temp=temp.sort_values(['Animal Type_outcomes','Count'],ascending=False).groupby('Animal Type_outcomes').head(5)
temp
# Out:
#      Animal Type_outcomes            Breed_outcomes  Count
# 1939                  Dog              Pit Bull Mix  15461
# 1572                  Dog    Labrador Retriever Mix  10939
# 899                   Dog   Chihuahua Shorthair Mix   8096
# 1306                  Dog       German Shepherd Mix   4885
# 1938                  Dog                  Pit Bull   2695
# 41                    Cat    Domestic Shorthair Mix  35632
# 40                    Cat        Domestic Shorthair  11239
# 36                    Cat  Domestic Medium Hair Mix   3602
# 29                    Cat     Domestic Longhair Mix   1808
# 87                    Cat               Siamese Mix   1510

# %%
import plotly.express as px

# %%
x1=temp[temp['Animal Type_outcomes']=='Dog']
x2=temp[temp['Animal Type_outcomes']=='Cat']

# %%
f, ax = plt.subplots(figsize=(18,5))
ax.set_xticklabels(temp['Breed_outcomes'],rotation=45)
plt.bar(x1['Breed_outcomes'],x1['Count'])
plt.bar(x2['Breed_outcomes'],x2['Count'])
# Out:
# <ipython-input-73-e2a26a165615>:2: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
# <BarContainer object of 5 artists>

# %% [markdown]
# Analytic 2: Most and least common animal types that enter the shelter

# %%
temp=df.groupby(['Animal Type_outcomes'])[['Animal ID']].count().reset_index()
temp.rename(columns={'Animal ID':'Count'},inplace=True)
temp
# Out:
#   Animal Type_outcomes   Count
# 0                 Bird     658
# 1                  Cat   57307
# 2                  Dog  112832
# 3            Livestock      24
# 4                Other    7378

# %%
f, ax = plt.subplots(figsize=(18,5))
ax.set_xticklabels(temp['Animal Type_outcomes'],rotation=45)
plt.bar(temp['Animal Type_outcomes'],temp['Count'])
# Out:
# <ipython-input-86-68d987b23a8e>:2: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
# <BarContainer object of 5 artists>
